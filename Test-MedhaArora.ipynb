# %% [markdown]
# <a href="https://colab.research.google.com/github/dsmed/Tech-Test-Full-Stack/blob/master/Test-MedhaArora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   **How long did you spend writing the application?**
#
#     I spend just an hour in writing the application and the answers.
#
# *   **What part of the application are you most proud of?**
#
#     I am most proud that I could build an assessment which is running for  60 seconds with the conditions mentioned. I am most proud that I could build up the similar assessment using Python. I could check for similar conditions.
#
# *   **If you had more time what would you improve in the application?**
#
#     I could have improved very much more by putting more time by firstly creating separate UI for the application. Then, I would have liked to redirect the number complexity to just one lower level instead of going to initial level if some wrong answer is thrown. Also, I would have liked to create some formulation for random number generation instead of hardcoding it.

# %%
import time
import random

correct = 0
wrong = 0
t_end = time.time() + 60 
print("The game begins")
#Executing the assessment for 60 secs only
while time.time() < t_end:
  a = random.randint(0,9)  #Starting with 1 digit number
  print(a)
  time.sleep(3)   # Displaying the number for 3 secons
  g = input("Enter the number : ")
  if(g and g.strip()):   # Checking if there is valid input and it is not null
    if a == int(g,10):    # Checking the input number and the random number generated
      correct+=1
      a1 = random.randint(10,99)  # Increasing the complexity to 2 digit number
      print(a1)
      time.sleep(3)
      g1 = input("Enter the number : ")
      if(g1 and g1.strip()):
        if a1 == int(g1,10):
          correct+=1
          a2 = random.randint(100,999)      # Increasing the complexity to 3 digit number
          print(a2)
          time.sleep(3)
          g2 = input("Enter the number : ")
          if(g2 and g2.strip()):
            if a2 == int(g2,10):
              correct+=1
              a3 = random.randint(1000,9999)     # Increasing the complexity to 4 digit number
              print(a3)
              time.sleep(3)
              g3 = input("Enter the number : ")
              if(g3 and g3.strip()):
                if a3 == int(g3,10):
                  correct+=1
                  a4 = random.randint(10000,99999)     # Increasing the complexity to 5 digit number
                  print(a4)
                  time.sleep(3)
                  g4 = input("Enter the number : ")
                  if(g4 and g4.strip()):
                    if a4 == int(g4,10):
                      correct+=1
                      a5 = random.randint(1000000,9999999)     # Increasing the complexity to 6 digit number
                      print(a5)
                      time.sleep(3)
                      g5 = input("Enter the number : ")
                      if(g5 and g5.strip()):
                        if a5 == int(g5,10):
                          correct+=1
                          a6 = random.randint(10000000,99999999)     # Increasing the complexity to 7 digit number
                          print(a6)
                          time.sleep(3)
                          g6 = input("Enter the number : ")
                          if(g6 and g6.strip()):
                            if a6 == int(g6,10):
                              correct+=1
                              a7 = random.randint(100000000,999999999)    # Increasing the complexity to 8 digit number
                              print(a7)
                              time.sleep(3)
                              g7 = input("Enter the number : ")
                              if(g7 and g7.strip()):
                                if a7 == int(g7,10):
                                  correct+=1
                                  a8 = random.randint(1000000000,9999999999)     # Increasing the complexity to 9 digit number
                                  print(a8)
                                  time.sleep(3)
                                  g8 = input("Enter the number : ")
                                  if(g8 and g8.strip()):
                                    if a8 == int(g8,10):
                                      correct+=1
                                    else:
                                      wrong+=1
                                else:
                                  wrong+=1
                            else:
                              wrong+=1
                        else:
                          wrong+=1
                    else:
                      wrong+=1
                else:
                  wrong+=1
            else:
              wrong+=1

    else:
      wrong+=1
  else:
    print("Please enter a valid input.")
print("The game is over and the results are:")
print("The number of correct responses were", correct)
print("The overall score was", (correct * 10))
